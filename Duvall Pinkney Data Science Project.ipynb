# %% [markdown]
# Duvall Pinkney Project Spring 2021
#
# Step 1: Choose your dataset
# Choose any interesting dataset that meets these criteria:
#
# in CSV format (or you have put it in this format)
# each row represents one observation
# at least four columns of data
# at least one column of qualitative (categorical) data with duplicate values
# at least two columns of quantitative data (integer or real number data that are measurements, not categorical data where the categories are numbers like zip codes)
# at least 30 rows of data
# The above criteria are a minimum, and you will have more choices for the project analysis if your data has more than 4 columns, more than 1 column of repeated categorical data, and more than 2 columns of quantitative data.  For Milestone 2, you will be trying to predict the category/value in one of the columns, using data from the other columns.
#
# Sources for finding your dataset:
#
# NYC Open Data (many other cities, states, and countries also provide open data)
# DataQuest's list of 21 places to find datasets for projects
# Awesome Public Datasets, organized by topic
# Kaggle   (this is a great site for finding cleaned data with a lot of useful variables/columns)
# data that you or a device you own (ex. fitbit) have collected
#
#
# Item
# Step 2: Create a GitHub account
# a) Create a GitHub account at https://github.com
#
# b) Create a new repository for your project.  See main Project page or Project sub-channel in the Video section for an introductory video to GitHub that shows how to create a new repository, add a file, and update a file.
#
# c) Upload your data file to this repository.  See main Project page or Project sub-channel in the Video section for an introductory video to GitHub that shows how to create a new repository, add a file, and update a file.
# https://github.com/Dpinkney001/Data-Science-MAT328-Project-Spring-2021
#
#
# Item
# Step 3: Create a webpage
# Create a webpage for your project. Easy, free ways to create a webpage (though you may use whatever you like):
# https://sites.google.com/view/dpinkney001/home
# sites.google.com. (recommended)
# www.wix.com
# See the video on the previous page or in the Project sub-channel (in the Video section) with instructions on creating a Google sites webpage.
#
#
#
# Item
# Step 4: Data Description and Assessment
# On your webpage:
#
# a) Write a paragraph introducing and describing your dataset to the reader.  Consider including the following information in the description:
#
# why you are interested in this data
# where you found the dataset (including link)
# who (person, government, organization, company, etc.) created the dataset
# what kind of information is contained in the dataset
# b) Assess the data by answering the questions in Lab 3:
#
# What is the structure or shape of the data?
# What is the granularity of the data?
# What is the scope and completeness of the data?
# What is the temporality of the data, or how does the data relate to time?
# What is the faithfulness of the data, or how well does the data capture reality?
#
#
# Item
# Step 5: Cleaning your data
# a) If necessary, clean your data (ex. handle missing and erroneous data, remove extra characters in quantitative data columns, etc).  As you explore your data in later steps, you may realize additional cleaning needs to be done.  If so, just come back and update this step.
#
# b) Describe what steps (if any) you took to clean your data on your webpage.
#
#
#
# Item
# Step 6: Single variable distribution plots
# Choose 4 columns and do the following for each of these columns:
#
# Plot the distribution of data in that column using an appropriate graph type.
# Add a title and axes labels to the plot.
# Add the plot to your webpage and write several sentences telling the reader what they should notice about the plot (ex. shape of distribution, outliers, skew, anything surprising, etc)
# Add your code for this step to your GitHub account.
#
#
#
# Item
# Step 7: Multiple variable plots
# Create 2 plots by doing the following for each:
#
# a) Choose two or more columns/variables, and create a plot visualizing their relationship.
#
# b) Add a title and axes labels to the plot.
#
# c) Add the plot to your webpage and write several sentences telling the reader what they should notice or conclude from this plot.
#
# Add the code for this step to your GitHub account.

# %%
import folium
import csv
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import os
import statsmodels.formula.api as smf

from sklearn.linear_model import LinearRegression

# %matplotlib inline

pd.set_option('display.max_columns', None)

# %%
bronxData = pd.read_csv("NYPD_Motor_Vehicle_Collisions_-_Crashes (bronx only).csv")

# %%
bronxData
# Out:
#               DATE   TIME BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 0       05/18/2017  11:00   BRONX   10475.0  40.880535 -73.832120
# 1       06/08/2017  10:00   BRONX   10458.0        NaN        NaN
# 2       05/31/2017  10:30   BRONX   10461.0  40.855618 -73.829575
# 3       06/01/2017   5:57   BRONX   10451.0  40.818558 -73.927320
# 4       06/01/2017   7:50   BRONX   10469.0  40.864240 -73.834460
# ...            ...    ...     ...       ...        ...        ...
# 153949  06/10/2013  11:10   BRONX   10468.0  40.864554 -73.901944
# 153950  06/12/2013  13:00   BRONX   10456.0  40.820297 -73.904108
# 153951  06/10/2013  17:30   BRONX   10466.0  40.899052 -73.846968
# 153952  06/09/2013   1:00   BRONX   10451.0  40.825414 -73.923475
# 153953  06/09/2013  18:10   BRONX   10458.0  40.862259 -73.895884
#
#                          LOCATION                    ON STREET NAME  \
# 0          (40.880535, -73.83212)  REEDS MILL LANE
# ...

# %%
bronxData.describe()
# Out:
#             ZIP CODE       LATITUDE      LONGITUDE  NUMBER OF PERSONS INJURED  \
# count  153950.000000  149148.000000  149148.000000              153953.000000
# mean    10462.123709      40.815625     -73.821338                   0.285555
# std         7.003998       1.168117       2.112392                   0.702769
# min     10451.000000       0.000000     -74.169876                   0.000000
# 25%     10457.000000      40.827656     -73.905610                   0.000000
# 50%     10462.000000      40.846359     -73.886186                   0.000000
# 75%     10468.000000      40.869656     -73.858654                   0.000000
# max     10803.000000      40.912884       0.000000                  31.000000
#
#        NUMBER OF PERSONS KILLED  NUMBER OF PEDESTRIANS INJURED  \
# count             153947.000000                  153954.000000
# mean                   0.001033                       0.068111
# std                    0.032323                       0.266935
# ...

# %%
bronxData.hist(bins = 25)
# Out:
# C:\Users\thees\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# C:\Users\thees\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# C:\Users\thees\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# ...

# %%
url = "NYPD_Motor_Vehicle_Collisions_-_Crashes (bronx only).csv"
df = pd.read_csv(url, na_values = "-")

# %%
zipcode_filter = df['ZIP CODE'] == 10458
df[zipcode_filter]
# Out:
#               DATE   TIME BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 1       06/08/2017  10:00   BRONX   10458.0        NaN        NaN
# 17      05/25/2017   9:00   BRONX   10458.0  40.860060 -73.891136
# 32      05/18/2017  11:00   BRONX   10458.0        NaN        NaN
# 34      05/30/2017   0:00   BRONX   10458.0  40.863960 -73.894600
# 37      06/09/2017   7:30   BRONX   10458.0  40.868366 -73.889810
# ...            ...    ...     ...       ...        ...        ...
# 153939  06/12/2013  20:43   BRONX   10458.0  40.864256 -73.888123
# 153942  06/12/2013  22:03   BRONX   10458.0  40.869522 -73.889893
# 153946  06/10/2013  11:45   BRONX   10458.0  40.856435 -73.886816
# 153948  06/09/2013  11:00   BRONX   10458.0  40.861831 -73.892852
# 153953  06/09/2013  18:10   BRONX   10458.0  40.862259 -73.895884
#
#                          LOCATION                    ON STREET NAME  \
# 1                             NaN  EAST FORDHAM ROAD
# 17         (40.86006, -73.891136)  3 AVENUE
# ...

# %%
my_neigborhood_data = df[zipcode_filter]
my_neigborhood_data.hist(bins = 25)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002986C5EBD88>,
# ...
#       dtype=object)

# %%
def accidentcount(df):
    index = 0
    for index in df:
        index += 1
    return str(index)

# %%
new_df = df[zipcode_filter]
new_df
# Out:
#               DATE   TIME BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 1       06/08/2017  10:00   BRONX   10458.0        NaN        NaN
# 17      05/25/2017   9:00   BRONX   10458.0  40.860060 -73.891136
# 32      05/18/2017  11:00   BRONX   10458.0        NaN        NaN
# 34      05/30/2017   0:00   BRONX   10458.0  40.863960 -73.894600
# 37      06/09/2017   7:30   BRONX   10458.0  40.868366 -73.889810
# ...            ...    ...     ...       ...        ...        ...
# 153939  06/12/2013  20:43   BRONX   10458.0  40.864256 -73.888123
# 153942  06/12/2013  22:03   BRONX   10458.0  40.869522 -73.889893
# 153946  06/10/2013  11:45   BRONX   10458.0  40.856435 -73.886816
# 153948  06/09/2013  11:00   BRONX   10458.0  40.861831 -73.892852
# 153953  06/09/2013  18:10   BRONX   10458.0  40.862259 -73.895884
#
#                          LOCATION                    ON STREET NAME  \
# 1                             NaN  EAST FORDHAM ROAD
# 17         (40.86006, -73.891136)  3 AVENUE
# ...

# %%
new_df.dropna()
# Out:
# Empty DataFrame
# Columns: [DATE, TIME, BOROUGH, ZIP CODE, LATITUDE, LONGITUDE, LOCATION, ON STREET NAME, CROSS STREET NAME, OFF STREET NAME, NUMBER OF PERSONS INJURED, NUMBER OF PERSONS KILLED, NUMBER OF PEDESTRIANS INJURED, NUMBER OF PEDESTRIANS KILLED, NUMBER OF CYCLIST INJURED, NUMBER OF CYCLIST KILLED, NUMBER OF MOTORIST INJURED, NUMBER OF MOTORIST KILLED, CONTRIBUTING FACTOR VEHICLE 1, CONTRIBUTING FACTOR VEHICLE 2, CONTRIBUTING FACTOR VEHICLE 3, CONTRIBUTING FACTOR VEHICLE 4, CONTRIBUTING FACTOR VEHICLE 5, COLLISION_ID, VEHICLE TYPE CODE 1, VEHICLE TYPE CODE 2, VEHICLE TYPE CODE 3, VEHICLE TYPE CODE 4, VEHICLE TYPE CODE 5]
# Index: []

# %%
new_df
# Out:
#               DATE   TIME BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 1       06/08/2017  10:00   BRONX   10458.0        NaN        NaN
# 17      05/25/2017   9:00   BRONX   10458.0  40.860060 -73.891136
# 32      05/18/2017  11:00   BRONX   10458.0        NaN        NaN
# 34      05/30/2017   0:00   BRONX   10458.0  40.863960 -73.894600
# 37      06/09/2017   7:30   BRONX   10458.0  40.868366 -73.889810
# ...            ...    ...     ...       ...        ...        ...
# 153939  06/12/2013  20:43   BRONX   10458.0  40.864256 -73.888123
# 153942  06/12/2013  22:03   BRONX   10458.0  40.869522 -73.889893
# 153946  06/10/2013  11:45   BRONX   10458.0  40.856435 -73.886816
# 153948  06/09/2013  11:00   BRONX   10458.0  40.861831 -73.892852
# 153953  06/09/2013  18:10   BRONX   10458.0  40.862259 -73.895884
#
#                          LOCATION                    ON STREET NAME  \
# 1                             NaN  EAST FORDHAM ROAD
# 17         (40.86006, -73.891136)  3 AVENUE
# ...

# %%
sns.pairplot(data = new_df)
# Out:
# C:\Users\thees\Anaconda3\lib\site-packages\numpy\lib\histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Users\thees\Anaconda3\lib\site-packages\numpy\lib\histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
new_df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000029804EDFE48>,
# ...
#       dtype=object)

# %%
new_df.describe()
# Out:
#        ZIP CODE     LATITUDE    LONGITUDE  NUMBER OF PERSONS INJURED  \
# count    8729.0  8103.000000  8103.000000                8729.000000
# mean    10458.0    40.811100   -73.797521                   0.269332
# std         0.0     1.434690     2.594269                   0.658774
# min     10458.0     0.000000   -74.070970                   0.000000
# 25%     10458.0    40.857168   -73.892570                   0.000000
# 50%     10458.0    40.860997   -73.888885                   0.000000
# 75%     10458.0    40.865922   -73.884415                   0.000000
# max     10458.0    40.880083     0.000000                   9.000000
#
#        NUMBER OF PERSONS KILLED  NUMBER OF PEDESTRIANS INJURED  \
# count               8728.000000                    8729.000000
# mean                   0.000802                       0.074006
# std                    0.028310                       0.279163
# min                    0.000000                       0.000000
# ...

# %%
plt.bar(x = new_df["NUMBER OF PERSONS INJURED"], height = 9000, data = new_df)
# Out:
# <BarContainer object of 8729 artists>

# %%
new_df["DATE"] = pd.to_datetime(new_df["DATE"])
new_df["DATE"]
# Out:
# C:\Users\thees\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# 1        2017-06-08
# 17       2017-05-25
# 32       2017-05-18
# 34       2017-05-30
# 37       2017-06-09
#             ...
# 153939   2013-06-12
# 153942   2013-06-12
# 153946   2013-06-10
# 153948   2013-06-09
# 153953   2013-06-09
# Name: DATE, Length: 8729, dtype: datetime64[ns]

# %%
new_df.plot(x = "DATE", y= "NUMBER OF PERSONS INJURED")

# %%
sns.relplot(x="DATE", y = "NUMBER OF PERSONS INJURED", data = new_df)

# %%
model_lr = LinearRegression()
model_lr.fit(new_df[['DATE']], new_df[['NUMBER OF PERSONS INJURED']])
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print(model_lr.coef_)
print(model_lr.intercept_)
# Out:
# [[-1.34283938e-19]]
# [0.46503374]

# %%
m = -1.34283938e-19   # slope
b = 0.46503374 # y-intercept

plt.plot(new_df['DATE'],new_df['NUMBER OF PERSONS INJURED'])
#x_coordinates = np.array([0,10000])
#y_coordinates = x_coordinates * -1.34283938e-19 + 0.46503374
#plt.plot(x_coordinates, y_coordinates, 'g-')

# %%
beta0 = 7.03
beta1 = 0.04

x1 = new_df.loc[1, 'DATE']
y1 = new_df.loc[1, 'NUMBER OF PERSONS INJURED'] 
print("x1, y1:", x1, y1)

# Calculate f(x1) = beta0 + beta1 * x1
prediction1 = beta0 + beta1 * x1
print("Prediction on Record 1:", prediction1)

# Calculate the squared error (y1 - f(x1)) ** 2
error1 = (y1 - prediction1) ** 2
print("Squared error on Record 1:", error1)
# Out:
# x1, y1: 2017-06-08 00:00:00 0.0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-53-688c745d714a> in <module>
#       7
#       8 # Calculate f(x1) = beta0 + beta1 * x1
# ----> 9 prediction1 = beta0 + beta1 * x1
#      10 print("Prediction on Record 1:", prediction1)
#      11
#
# TypeError: unsupported operand type(s) for *: 'float' and 'Timestamp'

# %%
lm = smf.ols("NUMBER OF PEDESTRIANS INJURED ~ DATE", data = new_df).fit()
lm.summary()
# Out:
# Traceback (most recent call last):
#
#   File "C:\Users\thees\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3326, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-115-553a6b4f88af>", line 1, in <module>
#     lm = smf.ols("NUMBER OF PEDESTRIANS INJURED ~ DATE", data = new_df).fit()
#
#   File "C:\Users\thees\Anaconda3\lib\site-packages\statsmodels\base\model.py", line 159, in from_formula
#     missing=missing)
#
#   File "C:\Users\thees\Anaconda3\lib\site-packages\statsmodels\formula\formulatools.py", line 65, in handle_formula_data
#     NA_action=na_action)
#
#   File "C:\Users\thees\Anaconda3\lib\site-packages\patsy\highlevel.py", line 310, in dmatrices
#     NA_action, return_type)
#
#   File "C:\Users\thees\Anaconda3\lib\site-packages\patsy\highlevel.py", line 165, in _do_highlevel_design
#     NA_action)
#
#   File "C:\Users\thees\Anaconda3\lib\site-packages\patsy\highlevel.py", line 70, in _try_incr_builders
# ...

# %%
plt.scatter(x = new_df["DATE"], y = lm.resid)
plt.xlabel("Actual accidents")
plt.ylabel("Residuals")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-113-792d19dfd930> in <module>
# ----> 1 plt.scatter(x = new_df["DATE"], y = lm.resid)
#       2 plt.xlabel("Actual accidents")
#       3 plt.ylabel("Residuals")
#
# NameError: name 'lm' is not defined

# %%
ml_df = new_df.groupby(["DATE","TIME","NUMBER OF PERSONS KILLED","NUMBER OF PERSONS INJURED"]).sum()
ml_df
# Out:
#                                                                      ZIP CODE  \
# DATE       TIME  NUMBER OF PERSONS KILLED NUMBER OF PERSONS INJURED
# 2012-07-02 14:48 0.0                      0.0                         10458.0
#            16:50 0.0                      0.0                         10458.0
# 2012-07-03 13:30 0.0                      0.0                         10458.0
#            14:10 0.0                      0.0                         10458.0
#            22:50 0.0                      1.0                         10458.0
# ...                                                                       ...
# 2019-10-12 22:00 0.0                      0.0                         10458.0
#            7:45  0.0                      0.0                         10458.0
# 2019-10-13 19:15 0.0                      0.0                         10458.0
#            3:00  0.0                      0.0                         10458.0
# ...

# %%
ml_df.corr()
# Out:
#                                ZIP CODE  LATITUDE  LONGITUDE  \
# ZIP CODE                       1.000000  0.327681  -0.327686
# LATITUDE                       0.327681  1.000000  -1.000000
# LONGITUDE                     -0.327686 -1.000000   1.000000
# NUMBER OF PEDESTRIANS INJURED  0.010025  0.016275  -0.016279
# NUMBER OF PEDESTRIANS KILLED  -0.002599  0.006016  -0.006017
# NUMBER OF CYCLIST INJURED      0.003897  0.002246  -0.002243
# NUMBER OF CYCLIST KILLED            NaN       NaN        NaN
# NUMBER OF MOTORIST INJURED     0.006245 -0.003670   0.003658
# NUMBER OF MOTORIST KILLED     -0.001061  0.002456  -0.002457
# COLLISION_ID                   0.177376 -0.130647   0.130609
#
#                                NUMBER OF PEDESTRIANS INJURED  \
# ZIP CODE                                            0.010025
# LATITUDE                                            0.016275
# LONGITUDE                                          -0.016279
# ...

# %%
new_df2 = df[zipcode_filter]
new_df2.dropna()
# Out:
# Empty DataFrame
# Columns: [DATE, TIME, BOROUGH, ZIP CODE, LATITUDE, LONGITUDE, LOCATION, ON STREET NAME, CROSS STREET NAME, OFF STREET NAME, NUMBER OF PERSONS INJURED, NUMBER OF PERSONS KILLED, NUMBER OF PEDESTRIANS INJURED, NUMBER OF PEDESTRIANS KILLED, NUMBER OF CYCLIST INJURED, NUMBER OF CYCLIST KILLED, NUMBER OF MOTORIST INJURED, NUMBER OF MOTORIST KILLED, CONTRIBUTING FACTOR VEHICLE 1, CONTRIBUTING FACTOR VEHICLE 2, CONTRIBUTING FACTOR VEHICLE 3, CONTRIBUTING FACTOR VEHICLE 4, CONTRIBUTING FACTOR VEHICLE 5, COLLISION_ID, VEHICLE TYPE CODE 1, VEHICLE TYPE CODE 2, VEHICLE TYPE CODE 3, VEHICLE TYPE CODE 4, VEHICLE TYPE CODE 5]
# Index: []

# %%
new_df2
# Out:
#               DATE   TIME BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 1       06/08/2017  10:00   BRONX   10458.0        NaN        NaN
# 17      05/25/2017   9:00   BRONX   10458.0  40.860060 -73.891136
# 32      05/18/2017  11:00   BRONX   10458.0        NaN        NaN
# 34      05/30/2017   0:00   BRONX   10458.0  40.863960 -73.894600
# 37      06/09/2017   7:30   BRONX   10458.0  40.868366 -73.889810
# ...            ...    ...     ...       ...        ...        ...
# 153939  06/12/2013  20:43   BRONX   10458.0  40.864256 -73.888123
# 153942  06/12/2013  22:03   BRONX   10458.0  40.869522 -73.889893
# 153946  06/10/2013  11:45   BRONX   10458.0  40.856435 -73.886816
# 153948  06/09/2013  11:00   BRONX   10458.0  40.861831 -73.892852
# 153953  06/09/2013  18:10   BRONX   10458.0  40.862259 -73.895884
#
#                          LOCATION                    ON STREET NAME  \
# 1                             NaN  EAST FORDHAM ROAD
# 17         (40.86006, -73.891136)  3 AVENUE
# ...

# %%
new_df2["DATE"] = pd.to_datetime(new_df2["DATE"])
new_df2["DATE"].dropna()
# Out:
# C:\Users\thees\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# 1        2017-06-08
# 17       2017-05-25
# 32       2017-05-18
# 34       2017-05-30
# 37       2017-06-09
#             ...
# 153939   2013-06-12
# 153942   2013-06-12
# 153946   2013-06-10
# 153948   2013-06-09
# 153953   2013-06-09
# Name: DATE, Length: 8729, dtype: datetime64[ns]

# %%
model_lr2 = LinearRegression()
model_lr2.fit(new_df2[['DATE']], new_df2[['NUMBER OF PERSONS KILLED']])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-104-5bcfe7d483bf> in <module>
#       1 model_lr2 = LinearRegression()
# ----> 2 model_lr2.fit(new_df2[['DATE']], new_df2[['NUMBER OF PERSONS KILLED']])
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in fit(self, X, y, sample_weight)
#     461         n_jobs_ = self.n_jobs
#     462         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 463                          y_numeric=True, multi_output=True)
#     464
#     465         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
# ...

# %%
print(model_lr2.coef_)
print(model_lr2.intercept_)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-105-b6e4f81d0e5c> in <module>
# ----> 1 print(model_lr2.coef_)
#       2 print(model_lr2.intercept_)
#
# AttributeError: 'LinearRegression' object has no attribute 'coef_'

# %%
m = model_lr2.coef_ #0, 0]   # slope
b = model_lr2.intercept_ #[0] # y-intercept

plt.plot(new_df2['DATE'], new_df2['NUMBER OF PERSONS KILLED'], 'b.')
x_coordinates = np.array([0,300])
y_coordinates = x_coordinates * m + b
plt.plot(x_coordinates, y_coordinates, 'g-')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-102-5f56cee8b662> in <module>
# ----> 1 m = model_lr2.coef_ #0, 0]   # slope
#       2 b = model_lr2.intercept_ #[0] # y-intercept
#       3
#       4 plt.plot(new_df2['DATE'], new_df2['NUMBER OF PERSONS KILLED'], 'b.')
#       5 x_coordinates = np.array([0,300])
#
# AttributeError: 'LinearRegression' object has no attribute 'coef_'

# %%
beta0 = 7.03
beta1 = 0.04

x1 = ml_df.loc[1, 'TIME']
y1 = ml_df.loc[1, 'NUMBER OF PERSONS INJURED'] 
print("x1, y1:", x1, y1)

# Calculate f(x1) = beta0 + beta1 * x1
prediction1 = beta0 + beta1 * x1
print("Prediction on Record 1:", prediction1)

# Calculate the squared error (y1 - f(x1)) ** 2
error1 = (y1 - prediction1) ** 2
print("Squared error on Record 1:", error1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.DatetimeEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.DatetimeEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 1
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\datetimes.py in get_loc(self, key, method, tolerance)
# ...

# %%
new_df.dropna()
# Out:
# Empty DataFrame
# Columns: [DATE, TIME, BOROUGH, ZIP CODE, LATITUDE, LONGITUDE, LOCATION, ON STREET NAME, CROSS STREET NAME, OFF STREET NAME, NUMBER OF PERSONS INJURED, NUMBER OF PERSONS KILLED, NUMBER OF PEDESTRIANS INJURED, NUMBER OF PEDESTRIANS KILLED, NUMBER OF CYCLIST INJURED, NUMBER OF CYCLIST KILLED, NUMBER OF MOTORIST INJURED, NUMBER OF MOTORIST KILLED, CONTRIBUTING FACTOR VEHICLE 1, CONTRIBUTING FACTOR VEHICLE 2, CONTRIBUTING FACTOR VEHICLE 3, CONTRIBUTING FACTOR VEHICLE 4, CONTRIBUTING FACTOR VEHICLE 5, COLLISION_ID, VEHICLE TYPE CODE 1, VEHICLE TYPE CODE 2, VEHICLE TYPE CODE 3, VEHICLE TYPE CODE 4, VEHICLE TYPE CODE 5]
# Index: []

# %%
df_filter = new_df[["LATITUDE","LONGITUDE","TIME"]]
new_df2 = df_filter.dropna()
new_df2
# Out:
#          LATITUDE  LONGITUDE   TIME
# 17      40.860060 -73.891136   9:00
# 34      40.863960 -73.894600   0:00
# 37      40.868366 -73.889810   7:30
# 45      40.861700 -73.891390  10:36
# 94      40.853650 -73.882744   7:55
# ...           ...        ...    ...
# 153939  40.864256 -73.888123  20:43
# 153942  40.869522 -73.889893  22:03
# 153946  40.856435 -73.886816  11:45
# 153948  40.861831 -73.892852  11:00
# 153953  40.862259 -73.895884  18:10
#
# [8103 rows x 3 columns]

# %%
m = folium.Map(location=[40.8747, -73.8951])
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
for i in range(8103):
    row = new_df2.iloc[i]
    folium.Marker([row["LATITUDE"],row["LONGITUDE"]]).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# i = 0
# for i in range(8103):
#     row = new_df2.iloc[i]
#     folium.Marker([row["LATITUDE"],row["LONGITUDE"]]).add_to(m)
# m

# %%
new_df2.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000206770FC0C8>,
# ...
#       dtype=object)

# %%
def clock():
    for hour in range(0,24):
        hour += 1
    return hour

# %%
hour = clock()

# %%
plt.bar(x = "TIME", height = 9000, data = new_df2)
#plt.axis([00:00,24:00,0,9000])
plt.title("Distribution of the Accident data")
plt.xlabel("time 00:00 - 24:00 hours")
plt.ylabel("number of accidents")
# Out:
# Text(0, 0.5, 'number of accidents')

# %%
plt.scatter(x = "TIME", y = new_df[""])
#plt.axis([0,24,0,9000])
plt.title("Distribution of the Accident data")
plt.xlabel("time 0 - 24hours")
plt.ylabel("number of accidents")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-68b1ceabfa38> in <module>
# ----> 1 plt.scatter(x = "TIME")
#       2 #plt.axis([0,24,0,9000])
#       3 plt.title("Distribution of the Accident data")
#       4 plt.xlabel("time 0 - 24hours")
#       5 plt.ylabel("number of accidents")
#
# TypeError: scatter() missing 1 required positional argument: 'y'

# %%
def dataAnalysis(df):
    for row in df:
        time = df["TIME"]
        location = row[2]
        c = time.find(":")
        hour = int(time[:c])
        if (hour >= 0) & (hour < 1):
            print(df[row])
                
        elif (hour >= 0) & (hour < 1):    
            print(df[row])
                
    minutes = hour / 60        
    plt.plot(minutes, len(row), color='green', marker='o', linestyle='solid')
    plt.title("Collision per hour in 10458")
    plt.axis([0,59,0,24])
    plt.xlabel("Hours")
    plt.ylabel("# of Collisions")
    #plt.show
    return minutes,len(row)
        
#

# %%
minutes, y = dataAnalysis(new_df)

plt.plot(minutes, y, color='green', marker='o', linestyle='solid')
plt.title("Collision per hour in 10458")
plt.axis([0,59,0,24])
plt.xlabel("Hours")
plt.ylabel("# of Collisions")
plt.show
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-e1cab3466d1d> in <module>
# ----> 1 minutes, y = dataAnalysis(new_df)
#       2
#       3 plt.plot(minutes, y, color='green', marker='o', linestyle='solid')
#       4 plt.title("Collision per hour in 10458")
#       5 plt.axis([0,59,0,24])
#
# <ipython-input-56-44c681aeec27> in dataAnalysis(df)
#       3         time = df["TIME"]
#       4         location = row[2]
# ----> 5         c = time.find(":")
#       6         hour = int(time[:c])
#       7         if (hour >= 0) & (hour < 1):
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
# ...

# %%
sns.relplot(x = "NUMBER OF PERSONS INJURED", y = "NUMBER OF PERSONS KILLED", data = new_df)

# %%
sns.relplot(x = "NUMBER OF PERSONS INJURED", y = "TIME", data = new_df)

# %%
sns.relplot(x = "NUMBER OF PERSONS KILLED", y = "TIME", data = new_df)

# %%
sns.relplot(x = "NUMBER OF MOTORIST INJURED", y = "NUMBER OF MOTORIST KILLED", data = new_df)

# %%
sns.relplot(x = "NUMBER OF MOTORIST INJURED", y = "TIME", data = new_df)

# %%
sns.relplot(x = "NUMBER OF MOTORIST KILLED", y = "TIME", data = new_df)
